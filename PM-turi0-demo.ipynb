# %% [markdown]
# <a href="https://colab.research.google.com/github/alimasumajja/PM-turi0-demo/blob/main/PM-turi0-demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

print('Numpy:', np.__version__)
print('Pandas:', pd.__version__)
print('Scikit-learn:', sklearn.__version__)
# Out:
# Numpy: 2.1.3
# Pandas: 2.2.3
# Scikit-learn: 1.6.1
